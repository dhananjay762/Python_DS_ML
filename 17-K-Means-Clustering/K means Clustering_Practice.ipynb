# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=101)

# %%
data[0].shape
# Out:
# (200, 2)

# %%
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')

# %%
data[1]
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 5.35167978,  6.20676329],
#        [-9.67203831, -5.13061964],
#        [-5.43564562,  7.56223985],
#        [-0.47545022,  4.08886774],
#        [ 0.33250207,  0.6136543 ],
#        [-2.41575022,  8.84918197],
#        [ 2.43300563,  7.87126525],
#        [-9.18960987, -8.53584776]])

# %%
kmeans.labels_
# Out:
# array([2, 0, 3, 6, 0, 1, 6, 4, 6, 3, 2, 3, 6, 6, 2, 4, 0, 4, 1, 5, 1, 4,
#        3, 7, 2, 7, 7, 4, 6, 0, 5, 7, 0, 4, 3, 2, 1, 1, 7, 4, 1, 5, 5, 5,
#        3, 6, 2, 3, 7, 3, 4, 2, 0, 4, 1, 3, 3, 4, 2, 6, 7, 6, 1, 5, 6, 4,
#        1, 0, 6, 1, 6, 3, 1, 3, 1, 0, 6, 4, 2, 3, 3, 1, 0, 1, 4, 4, 4, 2,
#        3, 1, 7, 1, 1, 3, 3, 7, 0, 2, 1, 0, 3, 1, 3, 4, 3, 3, 1, 0, 7, 1,
#        0, 5, 2, 6, 7, 0, 5, 2, 6, 5, 3, 2, 4, 2, 4, 0, 2, 4, 7, 5, 2, 5,
#        4, 7, 1, 2, 0, 3, 6, 4, 7, 0, 1, 5, 5, 6, 3, 7, 2, 2, 5, 5, 4, 0,
#        4, 2, 3, 6, 6, 4, 0, 4, 3, 2, 1, 2, 3, 0, 5, 4, 6, 4, 2, 6, 3, 2,
#        6, 6, 7, 6, 5, 7, 7, 5, 1, 7, 1, 7, 7, 4, 1, 0, 6, 2, 1, 3, 0, 0,
#        1, 4])

# %%
fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(10,6))

ax1.set_title('K Means')
ax1.scatter(data[0][:,0], data[0][:,1], c=kmeans.labels_, cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')
